# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# read data, change data path accordingly
edu = pd.read_csv("../data/edu.csv", encoding="latin1")
positions = pd.read_csv("../data/positions.csv", encoding="latin1")
users = pd.read_csv("../data/users.csv", encoding="latin1")

# %%
edu.head()
# Out:
#      USER_ID                                             SCHOOL STARTDATE  \
# 0  143224946                           East Carolina University       NaN
# 1  770116802         The State University of New York at Canton       NaN
# 2  792722937  The University of Tennessee Health Science Center  2023/1/1
# 3  807392056              University of Nebraska Medical Center  2016/1/1
# 4  807452334                            Northwestern University  2013/1/1
#
#      ENDDATE    DEGREE     FIELD                    DEGREE_RAW  \
# 0        NaN    Master     empty                          M.S.
# 1        NaN  Bachelor  Business                      Bachelor
# 2   2026/1/1    Doctor   Nursing    Doctor of Philosophy - PhD
# 3  2021/1/31    Doctor   Biology    Doctor of Philosophy (PhD)
# 4  2019/1/31    Doctor     empty  Doctor of Philosophy (Ph.D.)
#
#                                    FIELD_RAW      RSID  ULTIMATE_PARENT_RSID  \
# ...

# %%
positions.head()
# Out:
#       USER_ID          POSITION_ID                   COMPANY_RAW  \
# 0   147970206   215047511555946088              Primix Solutions
# 1   106795548 -1631847950681793423                     Time Inc.
# 2   106795548 -2029119152131192951  Valassis Marketing Solutions
# 3  2005181743  6200827261230535521           PSONE Art Education
# 4   103064330  6806342407096927817                        Macy's
#
#                             COMPANY_LINKEDIN_URL  \
# 0                                            NaN
# 1                 linkedin.com/company/time-inc-
# 2                  linkedin.com/company/valassis
# 3  linkedin.com/company/world-link-education-ltd
# 4                      linkedin.com/company/macy
#
#                 COMPANY_CLEANED  \
# 0              primix solutions
# 1                      time inc
# 2  valassis marketing solutions
# 3           psone art education
# 4                        macy s
#
#                                      LOCATION_RAW            REGION  \
# ...

# %%
users.head()
# Out:
#                                                TITLE  \
# 0  Chief of Chime Enterprise | Entrepreneur, Busi...
# 1  Chief of Chime Enterprise | Entrepreneur, Busi...
# 2  Chief of Chime Enterprise | Entrepreneur, Busi...
# 3  Chief of Chime Enterprise | Entrepreneur, Busi...
# 4  Chief of Chime Enterprise | Entrepreneur, Busi...
#
#                        USER_LOCATION  \
# 0  New York, New York, United States
# 1  New York, New York, United States
# 2  New York, New York, United States
# 3  New York, New York, United States
# 4  New York, New York, United States
#
#                                              SUMMARY  NUMCONNECTIONS  \
# 0  As the Chief of Chime Enterprise, I lead a hig...             500
# 1  As the Chief of Chime Enterprise, I lead a hig...             500
# 2  As the Chief of Chime Enterprise, I lead a hig...             500
# 3  As the Chief of Chime Enterprise, I lead a hig...             500
# ...

# %%
print(edu.shape, users.shape, positions.shape)
# Out:
# (11401, 25) (273074, 29) (39066, 35)

# %%
print("=== edu.csv columns ===")
print(list(edu.columns), "\n")

print("=== users.csv columns ===")
print(list(users.columns), "\n")

print("=== positions.csv columns ===")
print(list(positions.columns), "\n")
# Out:
# === edu.csv columns ===
# ['USER_ID', 'SCHOOL', 'STARTDATE', 'ENDDATE', 'DEGREE', 'FIELD', 'DEGREE_RAW', 'FIELD_RAW', 'RSID', 'ULTIMATE_PARENT_RSID', 'SCHOOL_PRESTIGE', 'CAMPUS_CLEANED', 'CAMPUS_COUNTRY', 'LOCATION_COUNTRY', 'UNIVERSITY_COUNTRY', 'IS_BAD_USER', 'IS_PLATFORM_USER', 'URI', 'EDUCATION_ID', 'DEGREE_LEVEL', 'SEQUENCENO', 'UNIVERSITYURL', 'UNIVERSITYURI', 'UNIVERSITY_LOCATION', 'EDUCATION_DESCRIPTION']
#
# === users.csv columns ===
# ['TITLE', 'USER_LOCATION', 'SUMMARY', 'NUMCONNECTIONS', 'F_PROB', 'M_PROB', 'WHITE_PROB', 'BLACK_PROB', 'API_PROB', 'HISPANIC_PROB', 'NATIVE_PROB', 'MULTIPLE_PROB', 'PRESTIGE', 'HIGHEST_DEGREE', 'EXPERTISE', 'CURRENTINDUSTRY', 'IS_BAD_USER', 'UPDATED_DT', 'PUB_NAME', 'PUB_DATE', 'PUB_DESCRIPTION', 'AWARD_NAME', 'AWARD_COMPANY', 'AWARD_DESCRIPTION', 'AWARD_DATE', 'CITY', 'STATE', 'COUNTRY', 'USER_ID']
#
# === positions.csv columns ===
# ...

# %%
# !pip install ydata_profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.5/669.5 kB 578.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 623.7 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 620.0 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ...

# %%
from ydata_profiling import ProfileReport

# profile = ProfileReport(df, 
#                         title="My Report", 
#                         explorative=True,   # more analysis and graphs if True
#                         minimal=True)       # faster with minimal mode


edu_report = ProfileReport(edu, title="EDA Report - edu.csv", minimal=True)
positions_report = ProfileReport(positions, title="EDA Report - positions.csv", minimal=True)

# save to HTML file
edu_report.to_file("edu_profiling_report.html")
positions_report.to_file("positions_profiling_report.html")

print("✅ Reports generated：edu_profiling_report.html, positions_profiling_report.html")
# Out:
# ...
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/Dolphin/opt/anaconda3/envs/jupyter6_env/lib/python3.9/site-packages/ydata_profiling/model/pandas/describe_numeric_pandas.py:133: RuntimeWarning: overflow encountered in scalar subtract
#   stats["range"] = stats["max"] - stats["min"]
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Reports generated：edu_profiling_report.html, positions_profiling_report.html

# %%
users_report = ProfileReport(users, title="EDA Report - users.csv", minimal=True)

users_report.to_file("users_profiling_report.html")

print("✅ Report generated：users_profiling_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Report generated：users_profiling_report.html
